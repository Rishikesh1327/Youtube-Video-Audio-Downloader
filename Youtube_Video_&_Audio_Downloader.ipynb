# %% [markdown]
# ---
#
# # **Youtube Video & Audio Downloader**
#
# ---

# %%
# Install tools
# !pip install -U yt-dlp
# !apt-get install -y ffmpeg

# Remove previously downloaded files
# !rm -f *.mp4 *.mp3

# Paste YouTube URL here
url = "PASTE_YOUR_YOUTUBE_VIDEO_URL_HERE"

# Select download type
print("Select Download Type:")
print("1 = Video (MP4 Highest Quality)")
print("2 = Audio (MP3 320kbps Highest Quality)")

choice = input("Enter 1 or 2: ")

# VIDEO DOWNLOAD
if choice == "1":
    print("Downloading Video...")
    # !yt-dlp -f "bestvideo+bestaudio/best" --merge-output-format mp4 -o "%(title)s.%(ext)s" "{url}"

# AUDIO DOWNLOAD
elif choice == "2":
    print("Downloading Audio...")
    # !yt-dlp -f bestaudio --extract-audio --audio-format mp3 --postprocessor-args "-b:a 320k" -o "%(title)s.%(ext)s" "{url}"

else:
    raise ValueError("Invalid choice. Restart and choose 1 or 2.")

# List downloaded files
# !ls

# Download the newest file to your computer
import os
from google.colab import files

files_list = [f for f in os.listdir() if f.endswith((".mp4",".mp3"))]

latest_file = max(files_list, key=os.path.getctime)

files.download(latest_file)
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.
# Select Download Type:
# 1 = Video (MP4 Highest Quality)
# 2 = Audio (MP3 320kbps Highest Quality)
# Enter 1 or 2: 2
# ...
# WARNING: Post-Processor arguments given without specifying name. The arguments will be given to all post-processors
# [youtube] Extracting URL: https://www.youtube.com/watch?v=GbBsODKiQKY
# [youtube] GbBsODKiQKY: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# ...
